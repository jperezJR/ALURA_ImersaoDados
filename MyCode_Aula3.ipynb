# %% [markdown]
# <a href="https://colab.research.google.com/github/jperezJR/ALURA_ImersaoDados/blob/main/MyCode_Aula3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importar biblioteca Pandas e ler aquivo de dados

import pandas as pd

dados = pd.read_csv('https://github.com/jperezJR/ALURA_ImersaoDados/blob/main/dados_experimentos.zip?raw=true', compression = 'zip')

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
#renomar coluna 'droga' para 'tratamento'

mapa = {'droga' : 'composto'}

dados.rename(columns = mapa, inplace = True)

dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
# criar uma tabela com cross-referencia de duas colunas

pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize= 'index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
import matplotlib.pyplot as plt

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento']).plot.bar(stacked=False)
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento']).plot.bar(stacked=True)
plt.show()

# %%
#analisar dados de somente 'g-0' considerando a media dos valores
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g-0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g-0'], aggfunc='mean').plot.bar()

# %%
# plotar grafico Scatter com dados de diferentes genes 

import seaborn as sns

sns.set()

sns.scatterplot(x='g-0', y='g-3', data=dados)

# %%
# definir curva de tendencia linear

sns.lmplot(data=dados, x='g-0', y='g-8', line_kws={'color': 'red'}, col='tratamento')
plt.show()

# %%
sns.lmplot(data=dados, x='g-0', y='g-8', line_kws={'color': 'red'}, col='tempo')
plt.show()

# %%
sns.lmplot(data=dados, x='g-0', y='g-8', line_kws={'color': 'red'}, col='tratamento', row='tempo')
plt.show()

# %%
# calcular a correlacao entre os valores de 'g-0' ate 'g-771'

#primero: realizar uma slice de somentes os valores de g's


dados.loc[:,'g-0':'g-771'].corr()
# Out:
#             g-0       g-1       g-2  ...     g-769     g-770     g-771
# g-0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g-1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g-2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g-3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g-4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...         ...       ...       ...  ...       ...       ...       ...
# g-767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g-768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g-769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g-770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g-771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
## fazer um grafico da matrix de correlacao entre os genes

import numpy as np


# Compute the correlation matrix
corr = dados.loc[:,'g-0':'g-50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# calcular agora a correlacao entre as celulas c-1 a c-50

corr_celulas = dados.loc[:,'c-1':'c-50'].corr()

# %%
# plotar o grafico de correlacao das celulas

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celulas, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celulas, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr_CeG = dados.loc[:,'g-0':].corr()

# %%
corr_CeG
# Out:
#            g-0       g-1       g-2  ...      c-97      c-98      c-99
# g-0   1.000000  0.086032  0.176188  ... -0.622840 -0.640484 -0.609238
# g-1   0.086032  1.000000 -0.054518  ... -0.008487 -0.002824 -0.002308
# g-2   0.176188 -0.054518  1.000000  ... -0.178812 -0.170152 -0.172124
# g-3   0.011266 -0.027855  0.042633  ... -0.049951 -0.079855 -0.037579
# g-4   0.403153  0.193647  0.013968  ... -0.394904 -0.366693 -0.390581
# ...        ...       ...       ...  ...       ...       ...       ...
# c-95 -0.600758 -0.011237 -0.158105  ...  0.811155  0.787529  0.758110
# c-96 -0.646784 -0.022127 -0.182540  ...  0.863061  0.819600  0.789649
# c-97 -0.622840 -0.008487 -0.178812  ...  1.000000  0.801809  0.775300
# c-98 -0.640484 -0.002824 -0.170152  ...  0.801809  1.000000  0.755991
# c-99 -0.609238 -0.002308 -0.172124  ...  0.775300  0.755991  1.000000
#
# [872 rows x 872 columns]

# %%
# plotar o grafico de correlacao entre as 50 expressoes genicas e os tipos celulares
corr= dados.loc[:,'g-0':'c-99'].corr()
corr_celular_genes = corr.loc['g-0':'g-50','c-0':'c-50']

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular_genes, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular_genes, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
